# %% [markdown]
# # 48. Rotate Image
# You are given an n x n 2D matrix representing an image, rotate the image by 90 degrees (clockwise).
#
# You have to rotate the image in-place, which means you have to modify the input 2D matrix directly. DO NOT allocate another 2D matrix and do the rotation.

# %% [markdown]
# ### Elegant Solution "Napkin Sketch" Explanation:
# Take a square napkin, and draw a picture on it. Now:
# 1. Transpose it - flip it on the diagonal (such that line from top left to bottom right remains unchanged)
# 2. Flip Horizontally
# The picture is now rotated 90° clockwise

# %%
class Solution:
    def rotate(self, matrix) -> None:
        n = len(matrix)
        # Transpose matrix
        for i in range(1,n):
            for j in range(i):
                matrix[i][j], matrix[j][i] = matrix[j][i], matrix[i][j]
        # Flip Horizontally
        for i in range(n):
            for j in range(int (n/2)):
                matrix[i][j], matrix[i][-(j+1)] = matrix[i][-(j+1)], matrix[i][j]

# %%
matrix = [[1,2],[3,4]]
Solution().rotate(matrix)
matrix
# Out:
# [[3, 1], [4, 2]]

# %% [markdown]
# ### Slightly Faster Solution
# Move elements directly where they need to go

# %%
class Solution:
    def rotate(self, matrix) -> None:
        n = len(matrix)
        for i in range(int (n/2)):
            for j in range(i, n-(1+i)):
                temp = matrix[j][i]
                matrix[j][i] = matrix[n-(i+1)][j]
                matrix[n-(i+1)][j] = matrix[n-(j+1)][n-(i+1)]
                matrix[n-(j+1)][n-(i+1)] = matrix[i][n-(j+1)]
                matrix[i][n-(j+1)] = temp

# %%
# Some code to make it easy to visualize the matrix
def printMatrix(matrix):
    m = len(matrix)
    n = len(matrix[0])
    for i in range(m):
        prnt_line = ""
        for j in range(n):
            prnt_line += matrix[i][j]
        print(prnt_line)

# %%
matrix = [[1,2,3],[4,5,6],[7,8,9]]

print(matrix)
Solution().rotate(matrix)
print(matrix)
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
# [[7, 4, 1], [8, 5, 2], [9, 6, 3]]

# %%
matrix = [[1,2,3],[4,5,6],[7,8,9]]
matrix = [[" "," "," "," "," "," "," "],
[" ","/","\\"," ","/","\\"," "],
["(","(","o","v","o",")",")"],
["(",")",":",":",":","(",")"],
[" "," ","V","V","V"," "," "],
[" "," "," "," "," "," "," "],
[" "," "," "," "," "," "," "]]

blank_lines = [" "]*100
matrix =[[".",".","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`"," "," "," "," ","`","`","`","`"," "," "," ","`"," "," "," ","`"," "," "," "," "," ","`"," ","`"," "," "," "," "," "," ","`","`","`","`"," "," ","`","`","`","`","`","`","`","`","`","`","`","`"],
[".",".","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`"," ","`","`","`","`"," "," ","`","`"," "," "," "," "," "," "," "," "," "," "," "," "," ","`","`","`"," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," ","`"," ","`","`"," "," "," "," ","`","`","`"],
[".","`","`","`","`",".","-","-",".","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`"," ","`","`","`"," "," ","`","`","`","`","`","`","`","`"," "," "," "," "," "," "," ","`"," ","`","`"," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," ","`"," "," "," "," "," "," "," "," "," "," "," "," "," "," ","`","`","`","`","`"," ","`"," ","`","`","`"],
[".",".","`","`","`",".",":",":",".","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`"," "," ","`",".",".","`","`","`","`",".","`"," "," ","`",".","`",".","`","`"," "," "," "," "," "," ","`"," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," ","`","`","`"," "," ","`"," "," ","`","`"],
[".",".","`","`","`",".",".","-",".","`","`","`","`","`","`","`","`","`"," "," ","`"," "," "," ","`","`","`","`"," "," "," "," "," "," "," "," ","`","-",".",".",".",".","`","`","`","`","`"," "," ","`"," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," ","`","`"," "," ","`"," "," ","`","`"],
[".","`",".",".","`",".","-","-",".","`","`","`","`","`","`","`"," "," "," "," ","`","`","`","`"," "," "," "," "," "," "," "," ","`","`",".",".",".",".",".",".","`","`",".",".","-","`","`","`",".","`"," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," ","`","`","`","`","`"," ","`","`","`","`","`","`","`","`"],
[".",".","-","-","`",".","`","-","-","`","`","`"," "," "," "," "," "," ","`",".","`"," "," "," "," "," ","`",".","`","."," ","`",".","-","-",":","/","/",".",".","-",".","-","-","`","-",".","-",".",".","`","`","`","`","`","`"," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," ","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`"],
[".",".",":",":",".",".",".","-","-",".","`","`","`","`","`","`",".",".","`"," "," "," "," "," ",".",".","-",".","-","y","h","+","+",":","+","h","h","m","s",".","-","`","`","-","-",".",".","-","-",".",".","`","`","`"," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," ","`"," "," "," "," ","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`"],
[".",".",":",":",".",".","/","-","-",".",".","`","`",".",".","`","`"," "," "," "," "," ","`","`","-","/",":","o","+","y","d","d","d","h","d","y","m","m","h","y","/",".","-",".","-","`","`","`","`","`","`","`",".",".",".","`","`"," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," ","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`"],
[".",".",":",":",".","-","-",".","-",".",".","`",".",".","`"," "," "," "," "," "," "," ",":","d","o","d","y","d","m","h","d","d","m","m","d","d","d","m","h","d","y","s","/","o",":","`","-",".","-",".",".","`",".",".",".",".",".","`"," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," ","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`"],
[".",".","-","-",".",".",".",".",".",".","-",".","`"," "," "," "," "," "," "," "," "," ",".","h","d","d","d","d","m","y","h","d","d","h","m","m","d","d","d","m","m","m","y",":","`",".","-",".","-",".",".","`",".",".","`","`",".",".","`"," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," ","`"," "," ","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`"],
["-",".",".",".",".",".",".","-","-",".","`"," "," "," "," "," "," "," "," "," "," "," "," ",".","/","o","+","o","y","y","h","m","h","d","d","h","d","h","d","d","h","y","o",":",".",".","-","-",".",".","-","`",".","-",".","-",".","`","`","`"," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," ","`"," "," "," "," "," "," "," "," "," "," "," "," "," "," ","`","`","`"],
["o","+","+","+","o","+","/","-","`"," "," "," "," ","`"," ","`",".","-"," "," "," "," "," ",".","`"," ","`","-","/","s","d","d","y","h","h","y","h","d","d","y","s","-","`","`"," ","`",".",".","-",".",".",".","`","`","-","-",".",".","`"," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," ","`"],
["y","s","o",":","-","`","`"," "," "," ","`",".","-",".","`","-",":","."," "," ","`"," ","`",":",".","-","-","`","/","o","+","/","o","y","h","h","d","m","h","y","."," "," "," "," "," ","`","`",".","`","`","`",".",".",".",".",".",".","`"," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," ","`","`"],
[".",".","`",".","`","`",".","-","`","`","-",":",".","`","`",".","-",".",":",".","-","`",".","-","`",".",".",".",".",".",".","-","/","+",":","+","s","h","h","y","`"," "," "," "," "," "," "," "," "," "," "," ",".","`",".",".","."," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," ","`","`"," "," "],
["`","`","`",".","-","-",":",":","-","-","o","h","s",":","+","-","-","`",":","-","-",".",":","y","o",":","o","o","s","-","-",".",".","-","o","y","y","d","h","o"," "," "," "," "," "," "," "," "," "," "," "," "," ","`","`"," ","`"," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," ","`","`"," "," "," ","."],
["`",".","-","-",":","-",":","-","-",".","+","y","s","d","h","o","`",".","-","-",".","`","`","+","o","o","+","h","h","s","y","+",":","o","s","d","h","d","d","o","`"," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," ","`","`"," "," "," ","`","`","-"],
[".",":","/",":","-","o","s",":","+","/",":","o","s","y","h","y","-","-","-",":","-","-","`",".","`","-","-","o","y","h","d","h","s","o","h","d","h","d","h","s","-"," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," ","`"," ","`","`","`"," "," "," ","`","`",".",":"],
[".","-","+","o","+","-","o","y","y","d","s","d","h","y","h","+","-",":","+","/","y","y","+",":","-",":","/","o","d","h","d","h","h","y","y","d","y","y","d","h","o",".","`","`","`","`","`","`","`","`"," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," "," ","`"," "," "," "," "," "," "," "," "," "," ","`","`","`","`","`","`","`","`","`",".",".",".","-","`"," "," ","`",".",".",":","+","s"],
[".",".",":",":",":","-","-","/","o","y","h","h","h","y","y","y","+","y","h","h","y","y","d","s","o","o","s","y","y","d","y","y","/","`",".",":","/","o","y","h","y","y","-","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`","`",".",".",".",".",".",".","-","-",":","o","/",".","`"," "," "," ","`",".",".",".","o","y","d"],
["-","-",".",".","-","-","`",".","-","/","/","o","y","h","h","h","h","h","y","h","d","h","h","h","d","h","h","h","y","s","s",":"," "," "," "," "," "," "," ",".","s","h","y","/","-","-","-","-","-","-",".",".",".",".",".",".",".",".",".",".",".",".",".",".",".",".",".",".",".",".","-","-","-","-","-",":",":",":",":",":",":","/","/","o","o","y","+","."," "," "," "," ","`",".","-","-","/","y","d","d"],
["-","-","-","-","-","-","`","`","-","/","/","-",":","+","o","s","y","y","h","h","d","h","y","y","h","h","y","y","/",".","`"," "," "," "," "," "," "," "," "," ","`","+","y","h","o","/",":",":","/","/","/","/","/","/","/","/","/","/","/","/","/","/","/",":","/","/","/","/","/","/","/","/","+","/","/","+","+","+","+","+","o","s","y","o","+","-","`"," "," "," "," ","-","+","o","y","h","h","y","d","h"],
["-",".","o","y","/","+","/","o","s","+","/","/","/","-",":",":",":","-","/","o","o","o","o","y","h","y","o",":"," "," "," "," "," "," ","`",".","`"," "," "," "," ","`","-","/","o","s","o","+","o","+","o","+","o","o","o","o","o","o","+","+","+","/",".","`","-","/","+","+","+","+","+","o","o","o","+","+","+","+","+","/","+","/",":",".","`","`","`",".","`","+","+","s","d","d","d","h","s","+",":","."],
["`","`","h","m","y","s","h","s","d","y","o","/","/","/","/",":","-","-","+","s","+","+",":","`","`","`"," "," "," "," "," ","`","`",".","-","."," "," "," "," "," "," ","`",".","`","`","-",".",":","o","o","o","o","s","o","o","o","o","o","/",".",".","`"," ","`","`","-","+","o","o","o","o","o","o","o","+","/",":","-",".","`","`"," "," ","`","`",":","+","+","s","h","y","o","+","/",":",".","`"," ","`"],
["`","`",".","s","h","y","h","d","h","d","h","y","+",":",":","/","/","-",":","/",":","."," "," "," "," "," "," ",".","`"," ",".",".",".",".","-","`","`","`"," ","`","`"," "," ",".",".",".",".","`","`",":","+","o","s","s","s","o","+","+","-","/","y","s","-","+","o",":",":","/","s","y","o",":","-","-","-",".",".","`",".",".",".",":",":","+",":",":",":",":","-","-",".","/","o","/","."," "," ","`","`"],
["`","`","`","`",".","-",":",":","/","-","-",".","`"," "," "," "," "," ","`","`","`","`"," "," "," ","`"," ",".",".",".",".",".",":","`",".","`","`",".",".",".",".","/",".","."," ","`",".","-",":","`","`","-","-",":","/","+","y","h","d","h","y","s","y","s","s","s","o","o","o","o","+","/","-",".",".",".",".","`",":","o","o","+","/",":","-",".",".",".","-",":","+","/","-","`","`","`","`",".",":","+"],
["`","`","`","`","`","`","`"," "," "," "," "," ","`","`"," "," "," "," ","`","-","-","`","`","`","`",".","-",".",".","-","`","`","`"," ","`",".",".","`",".","o",":","+","o","-",".","`",".",":","o","y",":","/","+",":",".","o","-",".","`",".","-","-","-",".",".",".",".","`","`","`",".",".",".","-","-","-",".","`",".",".",".",".","-",":",":","+","y","h","y","+",".","`","`","`",":",":","/","s","y","h"],
["`","`","`",".",".","-",".","-",".",".",".",".",".","`","`","-","`","`",".","-",".",".",".","."," "," "," "," "," ",".",".",".",".","`","`",".","-","`"," ","s","s","o",":",":",":","/","o",".",".","+","y","o","y","h","s","+","y","y","/","`"," "," "," "," "," "," "," "," "," "," ","`",".","`","`","`","`",".","-",".","-","+","o","s","s","s","s","+",":","`"," ","`","/","s","s","y","h","y","y","s","o"],
["`","`","`","`","`",".",".",".",":","-","-",".","`",".","-","h","o","-","-",".",".",".",".","`","`","`","."," ","`",".","-","-","`",":",".","-",".","."," ","-","h","y","y","s","/","+","o","o","/",":","-",":","/","s","d","d","y","s","y","h","o","-","`","`","`",":","/","-",".","`","`","-","/","/","+","o","o","s","s","s","y","y","h","y","o","-","`","`","`","`","`",".","-","/","+","s","y","y","y","h"],
["`","`","`",":","o","s","/","/","+","s","s","s","o","s","h","h","o","-","-","-","-",".","-",".","-","`","-",".",".",".","-",".","-",".","/","-","-","-","`"," ","/","d","h","d","d","s","/","+","/","/","+","+","/","/","+","o","o","y","y","h","d","d","h","s","+","-",":","o","h","h","s","o","o","s","s","y","o","s","s","+","s","o",":","`","`","`",".","/","+","+","s","h","h","s","+","+","o","o","o","o"],
["`",".","s","h","h","y","s","y","d","h","h","h","h","s",":",":",":",":","-","o","o","/","-",".",".",".",".",".","-",".","`",".","d","s","h","+","o",":","`",".","`",".","y","d","d","d","d","y","+",":",":",":","/","/","/","/","+",":",".","-","/","+","+","o","o","s","y","s","+","+","s","y","s","y","o","y","o","y","+","-","`"," ","`",":","/","/","+","+","+","o","o","o","o","o","s","d","d","d","d","m"],
["`","o","d","y","d","y","o","s","y","d","d","y","h","h","+","o","d","d","y","h","h","d","s","o","`",".","`","`",".","`"," "," ",".","/","+","y","d","+","/","s","-","`"," ","-","o","d","d","d","d","h","s","+",":","-",".",".","-","-",".",".","-","-","-","-","-","-","-","-","-","/",":","/","/","/","/","-",".","`",".","-",":",":","+","y","h","d","d","d","h","d","h","y","o","o","o","s","s","y","h","d"],
["`","y","d","d","y","h","d","d","s","m","h","d","d","m","h","d","h","d","d","h","d","d","m","y","`","`",".","-","h","h","-","-","/","h",":",":","s","d","y","d","m","/",":",".","`","`",":","s","h","m","m","d","d","y","o","+","/","/","/","+",":","-",":","/","+","/",":","-",".","`","`","`"," ",".","o","y","h","m","d","m","m","m","d","h","s","+",":",".","`","`","`","`","`","`","`","`","`","`","`","`"],
[":","d","y","h","d","d","d","m","d","h","m","h","m","m","h","d","d","d","d","h","m","d","d","y",":","o","+","y","/","/","-","/","+",":","-",".",":",":",":","s","d","d","d","o","/","/",".",".","`",".","-",":","/","+","+","o","o","o","o","+","+","/",":","-",".","`","`","`","`","`","`","`","`","`","`","`",".",".",".",".","`","`","`","`","`","`","`","`","`","`","`","`",".",".","`",".","`",".","`","."]]

for _ in range(100-34):
    matrix.append(blank_lines)

printMatrix(matrix)
Solution().rotate(matrix)
printMatrix(matrix)
# Out:
# ..``````````````````````````````````````````````````    ````   `   `     ` `      ````  ````````````
# ..```````````````````````` ````  ``             ```                                      ` ``    ```
# .````.--.````````````````` ```  ````````       ` ``                       `              ````` ` ```
# ..```.::.````````````````  `..````.`  `.`.``      `                                       ```  `  ``
# ..```..-.`````````  `   ````        `-....`````  `                                         ``  `  ``
# .`..`.--.```````    ````        ``......``..-```.`                                    ````` ````````
# ..--`.`--```      `.`     `.`. `.--://..-.--`-.-..``````                          ``````````````````
# ..::...--.``````..`     ..-.-yh++:+hhms.-``--..--..```                     `    ````````````````````
# ..::../--..``..``     ``-/:o+ydddhdymmhy/.-.-```````...``                   ````````````````````````
# ...
